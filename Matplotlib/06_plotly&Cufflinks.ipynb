# %% [markdown]
# Plotyly is Python library which is used to design graphs, especially interactive graphs and charts like hist, barplot, spreadplot and many mores
#
#
# Cufflinks Connects plotly with pandas to create graphs and charts of dataframes directly

# %%
# For installing anything using notebook we use
# !pip install plotly
# !pip install cufflinks

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'vscode'

# %%
tips=sns.load_dataset('tips')

# %%
# tips['total_bill'].iplot(color='#1f77b4')

px.line(tips,y='total_bill').show()

# %%
tips.groupby('day')['tip'].mean().iplot(kind='bag')

# %%
tips.iplot(kind='scatter',x='total_bill',y='tip',mode='markers')

# %%
tips[['total_bill','day']].iplot(kind='box',x='t')
